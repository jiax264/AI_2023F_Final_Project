# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib
import plotly.express as px
import plotly.graph_objects as go
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('../03_Data_for_Modeling/data_with_hour_for_clustering.csv')

# %%
df.sample(3)
# Out:
#         master_record_number  city  vehicles_involved  number_injured  \
# 205457             102817201    13                  2               0
# 79734              101583601    13                  2               0
# 128208             102069894    13                  2               0
#
#         number_dead  latitude  longitude  roadway_name  \
# 205457            0  36.15302  -86.69122          1139
# 79734             0  36.10831  -86.81071          2726
# 128208            0  36.15712  -86.76045          3401
#
#         intersection_indicator  intersect_type  relation_to_junction  \
# 205457                       0               2                     6
# 79734                        0               2                     6
# 128208                       1               6                     3
#
#         work_zone_type  weather_condition(s)  manner_of_crash  pedestrian  \
# 205457               1                     7                0           0
# 79734                1                     0                0           0
# 128208               1                     0                1           0
#
#         bicycle  scooter  parking  hitrun  mou  day_of_week  weekend  hour  \
# 205457        0        0        0       0    0            1        0    19
# 79734         0        0        0       0    0            2        0    10
# 128208        0        0        0       0    0            1        0    10
#
#         month  year  covid time_window
# 205457     10  2020      1       night
# 79734       3  2017      0     morning
# 128208      7  2018      0     morning

# %%
coords = df[['latitude', 'longitude']]
scaler = StandardScaler()
scaled_coords = scaler.fit_transform(coords)

# %%
dbscan = DBSCAN(eps=0.05, min_samples=5)  
clusters = dbscan.fit_predict(scaled_coords)
df['cluster'] = clusters

# %%
print(df['cluster'].value_counts())

# %%
plt.scatter(df['longitude'], df['latitude'], c=df['cluster'], cmap='Paired', marker='o')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('DBSCAN Clustering')
plt.colorbar(label='Cluster label')
plt.show()
