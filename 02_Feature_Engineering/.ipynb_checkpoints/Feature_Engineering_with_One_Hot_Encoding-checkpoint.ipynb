# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
folder = "../00_Raw_Data/"

# Generate filenames from 2015_Q1 to 2022_Q4
years = range(2015, 2023)
quarters = range(1, 5)

files = ["{}_Q{}_Traffic_Crashes.csv".format(year, quarter) for year in years for quarter in quarters]

dfs = [pd.read_csv(folder + file) for file in files]
df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ### Time-related feature engineering

# %%
df['collision_date'] = pd.to_datetime(df['collision_date'], format='%m/%d/%Y %I:%M:%S %p')
df['date'] = df['collision_date'].dt.date

df['day_of_week'] = df['collision_date'].dt.dayofweek # 0: Monday - 6: Sunday
df['weekend'] = df['day_of_week'].apply(lambda x: 1 if x in [5, 6] else 0)

day_map = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
df['day_name'] = df['day_of_week'].map(day_map)
day_onehot = pd.get_dummies(df['day_name'], prefix='day')
df = pd.concat([df, day_onehot], axis=1)

df['time'] = df['collision_date'].dt.time
df['hour'] = df['collision_date'].dt.hour
df['month'] = df['collision_date'].dt.month
month_map = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 
             7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}
df['month_name'] = df['month'].map(month_map)
month_onehot = pd.get_dummies(df['month_name'], prefix='month')
df = pd.concat([df, month_onehot], axis=1)

df['year'] = df['collision_date'].dt.year

def assign_season(month):
    if month in [12, 1, 2]:
        return 'winter'
    elif month in [3, 4, 5]:
        return 'spring'
    elif month in [6, 7, 8]:
        return 'summer'
    else:
        return 'fall'

df['season'] = df['month'].apply(assign_season)

season_onehot = pd.get_dummies(df['season'], prefix='season')
df = pd.concat([df, season_onehot], axis=1)
df.drop('season', axis=1, inplace=True)


def time_window(hour):
    if 23 <= hour or hour < 5:
        return 'late night'
    elif 5 <= hour < 11:
        return 'morning'
    elif 11 <= hour < 17:
        return 'afternoon'
    elif 17 <= hour < 23:
        return 'night'
    else:
        return 'unknown' 
    
df['covid'] = (df['date'] >= pd.Timestamp('2020-03-15').date()).astype(int)
df['time_window'] = df['hour'].apply(time_window)

# %% [markdown]
# ### Accident Related Feature Engineering

# %%
bins = [0, 1, 2, 3, 5, float('inf')]
labels = ['1 vehicle', '2 vehicles', '3 vehicles', '4-5 vehicles', '6+ vehicles']
df['vehicles_binned'] = pd.cut(df['vehicles_involved'], bins=bins, labels=labels, right=True, include_lowest=True)

vehicles_onehot = pd.get_dummies(df['vehicles_binned'], prefix='vehicles')
df = pd.concat([df, vehicles_onehot], axis=1)
df.drop('vehicles_binned', axis=1, inplace=True)

# %%
bins = [-1, 0, 1, 2, 4, 6, float('inf')]
labels = ['0 injured', '1 injured', '2 injured', '3-4 injured', '5-6 injured', '7+ injured']
df['injured_binned'] = pd.cut(df['number_injured'], bins=bins, labels=labels, right=True, include_lowest=True)

injured_onehot = pd.get_dummies(df['injured_binned'], prefix='injured')
df = pd.concat([df, injured_onehot], axis=1)
df.drop('injured_binned', axis=1, inplace=True)

# %%
bins = [-1, 0, 1, float('inf')]
labels = ['0 dead', '1 dead', '2+ dead']
df['dead_binned'] = pd.cut(df['number_dead'], bins=bins, labels=labels, right=True, include_lowest=True)

dead_onehot = pd.get_dummies(df['dead_binned'], prefix='dead')
df = pd.concat([df, dead_onehot], axis=1)
df.drop('dead_binned', axis=1, inplace=True)

# %%
df['manner_of_crash'] = df['manner_of_crash'].replace(['Missing', 'Unknown'], 'Unknown/Missing')

crash_onehot = pd.get_dummies(df['manner_of_crash'], prefix='crash')
df = pd.concat([df, crash_onehot], axis=1)

# %%
columns_to_convert = ['pedestrian', 'bicycle', 'scooter', 'hitrun', 'parking']

for column in columns_to_convert:
    df[column] = df[column].map({'yes': 1, 'no': 0})

# %% [markdown]
# ### location related feature engineering

# %%
# keep top 100 roads
top_100_roads = df['roadway_name'].value_counts().head(100).index

df['roadway_grouped'] = np.where(df['roadway_name'].isin(top_100_roads), df['roadway_name'], 'Other')

roadway_onehot = pd.get_dummies(df['roadway_grouped'], prefix='road')
df = pd.concat([df, roadway_onehot], axis=1)
df.drop('roadway_grouped', axis=1, inplace=True)

# %%
df['intersection_indicator'].fillna("N", inplace=True)
df['intersection_indicator'].replace("Missing", "N", inplace=True)
mapping = {"N": 0, "Y": 1}
df['intersection_encoded'] = df['intersection_indicator'].map(mapping)
df.drop('intersection_indicator', axis=1, inplace=True)

# %%
df['intersect_type'].replace(['OTHER', 'Missing', 'Unknown'], 'Unknown/Other', inplace=True)
intersect_type_onehot = pd.get_dummies(df['intersect_type'], prefix='intersect_type')
df = pd.concat([df, intersect_type_onehot], axis=1)
df.drop('intersect_type', axis=1, inplace=True)

# %%
df['relation_to_junction'].replace(['Missing', 'OtherLocation', 'Unknown'], 'Unknown/Other', inplace=True)
relation_onehot = pd.get_dummies(df['relation_to_junction'], prefix='relation_to_junction')
df = pd.concat([df, relation_onehot], axis=1)
df.drop('relation_to_junction', axis=1, inplace=True)

# %%
# Combine "Campus" and "OHO" categories
df['mou'] = df['mou'].replace('OHO', 'Campus')

# Now, encode "Campus" as 1 and "False" as 0
df['mou'] = df['mou'].apply(lambda x: 1 if x == 'Campus' else 0)

# %% [markdown]
# ### Environment related feature engineering

# %%
df['work_zone_present'] = df['work_zone_type'].apply(lambda x: 0 if x == "Missing" or x == "Unknown" else 1)

# %%
def simplify_weather(weather):
    if pd.isna(weather):
        return 'Unknown/Other'
    elif 'Snow' in weather:
        return 'Snow'
    elif 'Sleet/Hail' in weather:
        return 'Sleet/Hail'
    elif 'Rain' in weather:
        return 'Rain'
    elif weather in ['Fog', 'Smoke', 'Smog']:
        return 'Fog'
    elif 'Cloudy' in weather:
        return 'Cloudy'
    elif weather == 'Clear':
        return 'Clear'
    elif weather in ['Missing', 'Unknown', 'Other']:
        return 'Unknown/Other'
    else:
        return 'Other Conditions'


df['simplified_weather'] = df['weather_condition(s)'].apply(simplify_weather)
df = pd.get_dummies(df, columns=['simplified_weather'], prefix='weather')
df.drop('weather_condition(s)', axis=1, inplace=True)

# %% [markdown]
# ### drop cols won't be using

# %%
columns_to_drop = [
    "master_record_number", "agency", "agency_tracking_number", "county", "city", 
    "collision_date", "vehicles_involved", "number_injured", "number_dead", 
    "roadway_name", "roadway_suffix", "roadway_number", "roadway_local_id", 
    "distance_from_reference", "miles-feet_indicator", "direction_from_reference",
    "intersection_road_name", "intersection_road_name_suffix", "intersection_road_number",
    "intersection_local_id", "mile_marker", "interchange_related_indicator", 
    "work_zone_type", "construction_maintenance_zone", "construction_maintenance_zone_location",
    "fatal_case_number", "manner_of_crash", "date", "day_of_week", 
    "day_name", "month", "month_name", "officer_first_name", "officer_last_name"
]

df = df.drop(columns=columns_to_drop)

# %%
df.sample(5)
# Out:
#         latitude  longitude  pedestrian  bicycle  scooter  parking  hitrun  \
# 16095   36.12462  -86.80686           0        0        0        0       0
# 100843  36.16531  -86.79428           0        0        0        0       0
# 92377   36.23839  -86.67141           0        0        0        0       1
# 259187  36.17644  -86.76593           0        0        0        0       0
# 3513    36.11595  -86.78603           0        0        0        0       0
#
#         mou  weekend  day_Friday  day_Monday  day_Saturday  day_Sunday  \
# 16095     0        0       False       False         False       False
# 100843    0        0        True       False         False       False
# 92377     0        0       False       False         False       False
# 259187    0        0       False       False         False       False
# 3513      0        0       False       False         False       False
#
#         day_Thursday  day_Tuesday  day_Wednesday      time  hour  month_April  \
# 16095           True        False          False  18:14:00    18        False
# 100843         False        False          False  16:45:00    16        False
# 92377          False         True          False  15:05:00    15        False
# 259187         False         True          False  10:22:00    10         True
# 3513           False         True          False  16:24:00    16        False
#
#         month_August  month_December  month_February  month_January  \
# 16095          False           False           False          False
# 100843          True           False           False          False
# 92377          False           False           False          False
# 259187         False           False           False          False
# 3513           False           False            True          False
#
#         month_July  month_June  month_March  month_May  month_November  \
# 16095        False        True        False      False           False
# 100843       False       False        False      False           False
# 92377        False        True        False      False           False
# 259187       False       False        False      False           False
# 3513         False       False        False      False           False
#
#         month_October  month_September  year  season_fall  season_spring  \
# 16095           False            False  2015        False          False
# 100843          False            False  2017        False          False
# 92377           False            False  2017        False          False
# 259187          False            False  2022        False           True
# 3513            False            False  2015        False          False
#
#         season_summer  season_winter  covid time_window  vehicles_1 vehicle  \
# 16095            True          False      0       night               False
# 100843           True          False      0   afternoon               False
# 92377            True          False      0   afternoon               False
# 259187          False          False      1     morning               False
# 3513            False           True      0   afternoon               False
#
#         vehicles_2 vehicles  vehicles_3 vehicles  vehicles_4-5 vehicles  \
# 16095                  True                False                  False
# 100843                 True                False                  False
# 92377                  True                False                  False
# 259187                 True                False                  False
# 3513                  False                 True                  False
#
#         vehicles_6+ vehicles  injured_0 injured  injured_1 injured  \
# 16095                  False              False               True
# 100843                 False               True              False
# 92377                  False               True              False
# 259187                 False               True              False
# 3513                   False              False               True
#
#         injured_2 injured  injured_3-4 injured  injured_5-6 injured  \
# 16095               False                False                False
# 100843              False                False                False
# 92377               False                False                False
# 259187              False                False                False
# 3513                False                False                False
#
#         injured_7+ injured  dead_0 dead  dead_1 dead  dead_2+ dead  \
# 16095                False         True        False         False
# 100843               False         True        False         False
# 92377                False         True        False         False
# 259187               False         True        False         False
# 3513                 False         True        False         False
#
#         crash_Angle  crash_Front to Rear  crash_HeadOn  \
# 16095         False                 True         False
# 100843        False                 True         False
# 92377         False                 True         False
# 259187        False                 True         False
# 3513          False                 True         False
#
#         crash_Not Collision with Motor Vehicle in Transport  crash_Other  \
# 16095                                                 False        False
# 100843                                                False        False
# 92377                                                 False        False
# 259187                                                False        False
# 3513                                                  False        False
#
#         crash_Rear to Rear  crash_Rear to Side  \
# 16095                False               False
# 100843               False               False
# 92377                False               False
# 259187               False               False
# 3513                 False               False
#
#         crash_Sideswipe, Opposite Direction  crash_Sideswipe, Same Direction  \
# 16095                                 False                            False
# 100843                                False                            False
# 92377                                 False                            False
# 259187                                False                            False
# 3513                                  False                            False
#
#         crash_Unknown/Missing  road_-- UNKNOWN RAMP/ROAD --  road_12TH AVS  \
# 16095                   False                          True          False
# 100843                  False                         False          False
# 92377                   False                         False          False
# 259187                  False                         False          False
# 3513                    False                         False          False
#
#         road_14TH AVN  road_21ST AVS  road_28TH AVN  road_2ND AVS  \
# 16095           False          False          False         False
# 100843          False          False          False         False
# 92377           False          False          False         False
# 259187          False          False          False         False
# 3513            False          False          False         False
#
#         road_4TH AVS  road_8TH AVS  road_ANDREW JACKSON PKWY  \
# 16095          False         False                     False
# 100843         False         False                     False
# 92377          False         False                     False
# 259187         False         False                     False
# 3513           False         False                     False
#
#         road_ANTIOCH PKE  road_BELL RD  road_BRICK CHURCH PKE  \
# 16095              False         False                  False
# 100843             False         False                  False
# 92377              False         False                  False
# 259187             False         False                  False
# 3513               False         False                  False
#
#         road_BRILEY PKWY  road_BRILEY PKWYE  road_BRILEY PKWYN  \
# 16095              False              False              False
# 100843             False              False              False
# 92377              False              False              False
# 259187             False              False              False
# 3513               False              False              False
#
#         road_BRILEY PKWYS  road_BRILEY PKWYW  road_BROADWAY  road_CENTRAL PKE  \
# 16095               False              False          False             False
# 100843              False              False          False             False
# 92377               False              False          False             False
# 259187              False              False          False             False
# 3513                False              False          False             False
#
#         road_CHARLOTTE AV  road_CHARLOTTE PKE  road_CHURCH ST  \
# 16095               False               False           False
# 100843              False               False           False
# 92377               False               False           False
# 259187              False               False           False
# 3513                False               False           False
#
#         road_CLARKSVILLE PKE  road_CONFERENCE DR  road_DEMONBREUN ST  \
# 16095                  False               False               False
# 100843                 False               False               False
# 92377                  False               False               False
# 259187                 False               False               False
# 3513                   False               False               False
#
#         road_DICKERSON PKE  road_DIVISION ST  road_DONELSON PKE  \
# 16095                False             False              False
# 100843               False             False              False
# 92377                False             False              False
# 259187               False             False              False
# 3513                 False             False              False
#
#         road_DR D B TODD JR BLVD  road_E TRINITY LN  road_EDMONDSON PKE  \
# 16095                      False              False               False
# 100843                     False              False               False
# 92377                      False              False               False
# 259187                     False              False               False
# 3513                       False              False               False
#
#         road_ELLINGTON PKWYS  road_ELM HILL PKE  road_FRANKLIN PKE  \
# 16095                  False              False              False
# 100843                 False              False              False
# 92377                  False              False              False
# 259187                  True              False              False
# 3513                   False              False              False
#
#         road_GALLATIN AV  road_GALLATIN PKE  road_GALLATIN PKEN  \
# 16095              False              False               False
# 100843             False              False               False
# 92377              False              False               False
# 259187             False              False               False
# 3513               False              False               False
#
#         road_GALLATIN PKES  road_HAMILTON CHURCH RD  road_HARDING PKE  \
# 16095                False                    False             False
# 100843               False                    False             False
# 92377                False                    False             False
# 259187               False                    False             False
# 3513                 False                    False             False
#
#         road_HARDING PL  road_HAYWOOD LN  road_HERMITAGE AV  road_HIGHWAY 100  \
# 16095             False            False              False             False
# 100843            False            False              False             False
# 92377             False            False              False             False
# 259187            False            False              False             False
# 3513              False            False              False             False
#
#         road_HIGHWAY 70S  road_HILLSBORO PKE  road_I 24  road_I 40  \
# 16095              False               False      False      False
# 100843             False               False      False       True
# 92377              False               False      False      False
# 259187             False               False      False      False
# 3513               False               False      False      False
#
#         road_I 440  road_I 65  road_I24 E ENT RAMP  road_I24 E EXT RAMP  \
# 16095        False      False                False                False
# 100843       False      False                False                False
# 92377        False      False                False                False
# 259187       False      False                False                False
# 3513          True      False                False                False
#
#         road_I24 W ENT RAMP  road_I24 W EXT RAMP  road_I24E  \
# 16095                 False                False      False
# 100843                False                False      False
# 92377                 False                False      False
# 259187                False                False      False
# 3513                  False                False      False
#
#         road_I40 E ENT RAMP  road_I40 E EXT RAMP  road_I40 W ENT RAMP  \
# 16095                 False                False                False
# 100843                False                False                False
# 92377                 False                False                False
# 259187                False                False                False
# 3513                  False                False                False
#
#         road_I40 W EXT RAMP  road_I65 N ENT RAMP  road_I65 N EXT RAMP  \
# 16095                 False                False                False
# 100843                False                False                False
# 92377                 False                False                False
# 259187                False                False                False
# 3513                  False                False                False
#
#         road_I65 S ENT RAMP  road_I65 S EXT RAMP  road_JAMES ROBERTSON PKWY  \
# 16095                 False                False                      False
# 100843                False                False                      False
# 92377                 False                False                      False
# 259187                False                False                      False
# 3513                  False                False                      False
#
#         road_JEFFERSON ST  road_LAFAYETTE ST  road_LEBANON PKE  road_MAIN ST  \
# 16095               False              False             False         False
# 100843              False              False             False         False
# 92377               False              False             False         False
# 259187              False              False             False         False
# 3513                False              False             False         False
#
#         road_MCGAVOCK PKE  road_MT VIEW RD  road_MURFREESBORO PKE  \
# 16095               False            False                  False
# 100843              False            False                  False
# 92377               False            False                  False
# 259187              False            False                  False
# 3513                False            False                  False
#
#         road_MYATT DR  road_NEELYS BEND RD  road_NOLENSVILLE PKE  \
# 16095           False                False                 False
# 100843          False                False                 False
# 92377           False                 True                 False
# 259187          False                False                 False
# 3513            False                False                 False
#
#         road_OLD HICKORY BLVD  road_OLD HICKORY BLVDW  road_Other  \
# 16095                   False                   False       False
# 100843                  False                   False       False
# 92377                   False                   False       False
# 259187                  False                   False       False
# 3513                    False                   False       False
#
#         road_POWELL AV  road_ROSA L PARKS BLVD  road_SHELBY AV  \
# 16095            False                   False           False
# 100843           False                   False           False
# 92377            False                   False           False
# 259187           False                   False           False
# 3513             False                   False           False
#
#         road_SMITH SPRINGS RD  road_SPRING ST  road_STATE HWY 155  \
# 16095                   False           False               False
# 100843                  False           False               False
# 92377                   False           False               False
# 259187                  False           False               False
# 3513                    False           False               False
#
#         road_STATE HWY 254  road_STATE HWY 255  road_STATE HWY 45  \
# 16095                False               False              False
# 100843               False               False              False
# 92377                False               False              False
# 259187               False               False              False
# 3513                 False               False              False
#
#         road_STATE RT 45  road_STEWARTS FERRY PKE  road_THOMPSON LN  \
# 16095              False                    False             False
# 100843             False                    False             False
# 92377              False                    False             False
# 259187             False                    False             False
# 3513               False                    False             False
#
#         road_US HWY 31 ALT  road_US HWY 31E  road_US HWY 41  road_US HWY 431  \
# 16095                False            False           False            False
# 100843               False            False           False            False
# 92377                False            False           False            False
# 259187               False            False           False            False
# 3513                 False            False           False            False
#
#         road_US HWY 70  road_US HWY 70S  road_W TRINITY LN  road_WEDGEWOOD AV  \
# 16095            False            False              False              False
# 100843           False            False              False              False
# 92377            False            False              False              False
# 259187           False            False              False              False
# 3513             False            False              False              False
#
#         road_WEST END AV  road_WHITE BRIDGE PKE  road_WHITES CREEK PKE  \
# 16095              False                  False                  False
# 100843             False                  False                  False
# 92377              False                  False                  False
# 259187             False                  False                  False
# 3513               False                  False                  False
#
#         road_WOODMONT BLVD  intersection_encoded  \
# 16095                False                     0
# 100843               False                     0
# 92377                False                     1
# 259187               False                     0
# 3513                 False                     0
#
#         intersect_type_Five Point Or More  intersect_type_Four-Way  \
# 16095                               False                    False
# 100843                              False                    False
# 92377                               False                     True
# 259187                              False                    False
# 3513                                False                    False
#
#         intersect_type_Not at Intersection  intersect_type_Roundabout  \
# 16095                                 True                      False
# 100843                                True                      False
# 92377                                False                      False
# 259187                                True                      False
# 3513                                  True                      False
#
#         intersect_type_T-Intersection  intersect_type_Traffic Circle  \
# 16095                           False                          False
# 100843                          False                          False
# 92377                           False                          False
# 259187                          False                          False
# 3513                            False                          False
#
#         intersect_type_Unknown/Other  intersect_type_Y-Intersection  \
# 16095                          False                          False
# 100843                         False                          False
# 92377                          False                          False
# 259187                         False                          False
# 3513                           False                          False
#
#         relation_to_junction_AccelDecelLane  \
# 16095                                 False
# 100843                                False
# 92377                                 False
# 259187                                False
# 3513                                  False
#
#         relation_to_junction_Crossover-Related  \
# 16095                                    False
# 100843                                   False
# 92377                                    False
# 259187                                   False
# 3513                                     False
#
#         relation_to_junction_Driveway, Alley Access, etc  \
# 16095                                              False
# 100843                                             False
# 92377                                              False
# 259187                                             False
# 3513                                               False
#
#         relation_to_junction_Entrance/Exit Ramp Related  \
# 16095                                              True
# 100843                                            False
# 92377                                             False
# 259187                                            False
# 3513                                              False
#
#         relation_to_junction_Intersection  \
# 16095                               False
# 100843                              False
# 92377                                True
# 259187                              False
# 3513                                False
#
#         relation_to_junction_Intersection-Related  \
# 16095                                       False
# 100843                                      False
# 92377                                       False
# 259187                                      False
# 3513                                        False
#
#         relation_to_junction_Non-Junction  \
# 16095                               False
# 100843                               True
# 92377                               False
# 259187                               True
# 3513                                 True
#
#         relation_to_junction_Rail Grade Crossing  \
# 16095                                      False
# 100843                                     False
# 92377                                      False
# 259187                                     False
# 3513                                       False
#
#         relation_to_junction_SharedUsePathOrTrail  \
# 16095                                       False
# 100843                                      False
# 92377                                       False
# 259187                                      False
# 3513                                        False
#
#         relation_to_junction_Unknown/Other  work_zone_present  weather_Clear  \
# 16095                                False                  1           True
# 100843                               False                  1           True
# 92377                                False                  1          False
# 259187                               False                  1          False
# 3513                                 False                  1           True
#
#         weather_Cloudy  weather_Fog  weather_Other Conditions  weather_Rain  \
# 16095            False        False                     False         False
# 100843           False        False                     False         False
# 92377             True        False                     False         False
# 259187           False        False                     False          True
# 3513             False        False                     False         False
#
#         weather_Sleet/Hail  weather_Snow  weather_Unknown/Other
# 16095                False         False                  False
# 100843               False         False                  False
# 92377                False         False                  False
# 259187               False         False                  False
# 3513                 False         False                  False

# %%
df['time'] = df['time'].astype(str)
df['time'] = df['time'].str.strip()

missing_time_df = df[df['time'] == "00:00:00"] 
has_time_df = df[df['time'] != "00:00:00"]

# %%
columns_to_drop = [
    "time",
    "hour"
]
missing_time_df = missing_time_df.drop(columns=columns_to_drop)

# %%
def time_window(hour):
    if 23 <= hour or hour < 5:
        return 'late night'
    elif 5 <= hour < 11:
        return 'morning'
    elif 11 <= hour < 17:
        return 'afternoon'
    elif 17 <= hour < 23:
        return 'night'
    else:
        return 'unknown' 

has_time_df = has_time_df.copy()
has_time_df['time_window'] = has_time_df['hour'].apply(time_window)

# %%
columns_to_drop = [
    "time",
    "hour"
]
has_time_df = has_time_df.drop(columns=columns_to_drop)

# %%
train_df, temp_df = train_test_split(has_time_df, test_size=0.3, stratify=has_time_df['time_window'], random_state=42)

valid_df, test_df = train_test_split(temp_df, test_size=1/3, stratify=temp_df['time_window'], random_state=42)

print("Training set:", len(train_df))
print("Validation set:", len(valid_df))
print("Testing set:", len(test_df))
# Out:
# Training set: 183941
# Validation set: 52554
# Testing set: 26278

# %%
def print_value_counts(df, df_name):
    print(f"--- {df_name} ---")
    print(df['time_window'].value_counts())
    print("\n")

print_value_counts(train_df, "Training set")
print_value_counts(valid_df, "Validation set")
print_value_counts(test_df, "Testing set")
# Out:
# --- Training set ---
# time_window
# afternoon     72309
# night         52011
# morning       44885
# late night    14736
# Name: count, dtype: int64
#
#
# --- Validation set ---
# time_window
# afternoon     20659
# night         14860
# morning       12824
# late night     4211
# Name: count, dtype: int64
#
#
# --- Testing set ---
# time_window
# afternoon     10330
# night          7430
# morning        6413
# late night     2105
# Name: count, dtype: int64

# %%
def bool_to_int(df):
    for col in df.select_dtypes(['bool']).columns:
        df[col] = df[col].astype(int)
    return df

train_df = bool_to_int(train_df)
valid_df = bool_to_int(valid_df)
test_df = bool_to_int(test_df)

# %%
train_df.to_csv("../03_Data_for_Modeling/train.csv", index=False)
valid_df.to_csv("../03_Data_for_Modeling/valid.csv", index=False)
test_df.to_csv("../03_Data_for_Modeling/test.csv", index=False)
